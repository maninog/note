# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import mean_squared_error, r2_score

SEED = 12345

INPUT_FILE = "data_v9.csv"
OUTPUT_FILE = "sub_lightgbm_v9_3_5.csv"

# %%
from google.colab import drive
drive.mount("/content/drive/")
INPUT_PATH_1 = "/content/drive/My Drive/HousePrices/input/"
INPUT_PATH_2 = "/content/drive/My Drive/HousePrices/features/"
OUTPUT_PATH = "/content/drive/My Drive/HousePrices/prediction/"
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
df = pd.read_csv(INPUT_PATH_2 + INPUT_FILE)
print(df.shape)
df.head(3)
# Out:
# (2919, 42)
#      Id  GrLivArea  TotalBsmtSF  LotArea  BsmtFinSF1  GarageArea  OverallQual  \
# 0   784       1110         1097     9101        1097         602            5
# 1  1804        941          941     8604         941         564            5
# 2   880        864          864     7000         646         336            5
#
#    1stFlrSF  YearBuilt  LotFrontage  ...  TotalBsmtSF_BY_YearBuilt  \
# 0      1110       1978           74  ...                        58
# 1       941       1978           75  ...                       -97
# 2       864       1978           70  ...                      -174
#
#    GarageArea_BY_Neighborhood  GarageArea_BY_OverallQual  \
# 0                         100                        217
# 1                         140                        179
# 2                        -233                        -48
#
#    GarageArea_BY_YearBuilt  1stFlrSF_BY_Neighborhood  1stFlrSF_BY_OverallQual  \
# 0                       89                       -83                       40
# 1                       51                      -234                     -128
# 2                     -176                      -309                     -205
#
#    1stFlrSF_BY_YearBuilt  YearRemodAdd_BY_Neighborhood  \
# 0                    -74                            -7
# 1                   -243                             7
# 2                   -320                             5
#
#    YearRemodAdd_BY_OverallQual  YearRemodAdd_BY_YearBuilt
# 0                            4                         -2
# 1                            4                         -2
# 2                           31                         24
#
# [3 rows x 42 columns]

# %%
x_train = df.loc[(df['train_test'].isin([1,2])), :].drop(columns=['train_test','SalePrice','Id'], axis=1)
y_train = df.loc[(df['train_test'].isin([1,2])), :]['SalePrice']
y_train = np.log(y_train)
print(x_train.shape)
print(y_train.shape)
x_train.head(3)
# Out:
# (1460, 39)
# (1460,)
#    GrLivArea  TotalBsmtSF  LotArea  BsmtFinSF1  GarageArea  OverallQual  \
# 0       1110         1097     9101        1097         602            5
# 2        864          864     7000         646         336            5
# 3       1040         1040     8430         616           0            5
#
#    1stFlrSF  YearBuilt  LotFrontage  Neighborhood  ...  \
# 0      1110       1978           74            11  ...
# 2       864       1978           70             5  ...
# 3      1040       1978           60             5  ...
#
#    TotalBsmtSF_BY_YearBuilt  GarageArea_BY_Neighborhood  \
# 0                        58                         100
# 2                      -174                        -233
# 3                         1                        -569
#
#    GarageArea_BY_OverallQual  GarageArea_BY_YearBuilt  \
# 0                        217                       89
# 2                        -48                     -176
# 3                       -384                     -512
#
#    1stFlrSF_BY_Neighborhood  1stFlrSF_BY_OverallQual  1stFlrSF_BY_YearBuilt  \
# 0                       -83                       40                    -74
# 2                      -309                     -205                   -320
# 3                      -133                      -29                   -144
#
#    YearRemodAdd_BY_Neighborhood  YearRemodAdd_BY_OverallQual  \
# 0                            -7                            4
# 2                             5                           31
# 3                           -21                            4
#
#    YearRemodAdd_BY_YearBuilt
# 0                         -2
# 2                         24
# 3                         -2
#
# [3 rows x 39 columns]

# %%
model_list = []
rmse_list = []
r2_list = []
cat_cols = ['Neighborhood','MoSold','YearBuilt']
#cat_cols = ['OverallQual','Neighborhood','OverallCond','BsmtFinType1','MoSold']

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
#skf = KFold(n_splits=5, shuffle=True, random_state=SEED)
for idx_train, idx_valid in list(skf.split(x_train, x_train['Neighborhood'])):
#for idx_train, idx_valid in list(skf.split(x_train, y_train)):
    x_cv = x_train.iloc[idx_train]
    y_cv = y_train.iloc[idx_train]
    x_valid = x_train.iloc[idx_valid]
    y_valid = y_train.iloc[idx_valid]
    #
    model = lgb.LGBMRegressor(random_state=SEED, verbose=-1)
    model.fit(x_cv, y_cv, eval_set=[(x_valid, y_valid)], categorical_feature=cat_cols, callbacks=[lgb.early_stopping(stopping_rounds=10), lgb.log_evaluation()])
    #model.fit(x_cv, y_cv, eval_set=[(x_valid, y_valid)], callbacks=[lgb.early_stopping(stopping_rounds=10), lgb.log_evaluation()])
    pred_valid = model.predict(x_valid)
    model_list.append(model)
    rmse_list.append(mean_squared_error(y_valid, pred_valid, squared=False))
    #rmse_list.append(mean_squared_error(np.log(y_valid), np.log(pred_valid), squared=False))
    r2_list.append(r2_score(y_valid, pred_valid))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:2068: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['MoSold', 'Neighborhood', 'YearBuilt']
#   _log_warning('categorical_feature in Dataset is overridden.\n'
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [1]	valid_0's l2: 0.134809
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's l2: 0.115338
# [3]	valid_0's l2: 0.0995675
# [4]	valid_0's l2: 0.0862057
# [5]	valid_0's l2: 0.0748179
# [6]	valid_0's l2: 0.0656229
# [7]	valid_0's l2: 0.0576664
# [8]	valid_0's l2: 0.0512315
# [9]	valid_0's l2: 0.0459913
# [10]	valid_0's l2: 0.0418518
# [11]	valid_0's l2: 0.03804
# [12]	valid_0's l2: 0.0346154
# [13]	valid_0's l2: 0.0319486
# [14]	valid_0's l2: 0.0296626
# [15]	valid_0's l2: 0.0276647
# [16]	valid_0's l2: 0.0259126
# [17]	valid_0's l2: 0.0246498
# [18]	valid_0's l2: 0.0235081
# [19]	valid_0's l2: 0.0223855
# [20]	valid_0's l2: 0.0216311
# [21]	valid_0's l2: 0.0208698
# [22]	valid_0's l2: 0.0202743
# [23]	valid_0's l2: 0.0196986
# [24]	valid_0's l2: 0.0193329
# [25]	valid_0's l2: 0.0189821
# [26]	valid_0's l2: 0.0185979
# [27]	valid_0's l2: 0.0183586
# [28]	valid_0's l2: 0.0180621
# [29]	valid_0's l2: 0.017828
# [30]	valid_0's l2: 0.0175413
# [31]	valid_0's l2: 0.0172821
# [32]	valid_0's l2: 0.0171466
# [33]	valid_0's l2: 0.0170298
# [34]	valid_0's l2: 0.0168614
# [35]	valid_0's l2: 0.016809
# [36]	valid_0's l2: 0.0166763
# [37]	valid_0's l2: 0.0165587
# [38]	valid_0's l2: 0.0164593
# [39]	valid_0's l2: 0.0163851
# [40]	valid_0's l2: 0.0162852
# [41]	valid_0's l2: 0.0163079
# [42]	valid_0's l2: 0.0162517
# [43]	valid_0's l2: 0.0162817
# [44]	valid_0's l2: 0.0162181
# [45]	valid_0's l2: 0.0162747
# [46]	valid_0's l2: 0.016258
# [47]	valid_0's l2: 0.0162602
# [48]	valid_0's l2: 0.0162298
# [49]	valid_0's l2: 0.0162038
# [50]	valid_0's l2: 0.0161996
# [51]	valid_0's l2: 0.0162188
# [52]	valid_0's l2: 0.016217
# [53]	valid_0's l2: 0.016158
# [54]	valid_0's l2: 0.0160868
# [55]	valid_0's l2: 0.0160601
# [56]	valid_0's l2: 0.0160967
# [57]	valid_0's l2: 0.0161277
# [58]	valid_0's l2: 0.0160864
# [59]	valid_0's l2: 0.0160934
# [60]	valid_0's l2: 0.0160733
# [61]	valid_0's l2: 0.0160952
# [62]	valid_0's l2: 0.0161224
# [63]	valid_0's l2: 0.0161339
# [64]	valid_0's l2: 0.0161252
# [65]	valid_0's l2: 0.0161248
# Early stopping, best iteration is:
# [55]	valid_0's l2: 0.0160601
# [1]	valid_0's l2: 0.128492
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's l2: 0.110686
# [3]	valid_0's l2: 0.0956983
# [4]	valid_0's l2: 0.0842025
# [5]	valid_0's l2: 0.0739628
# [6]	valid_0's l2: 0.0658669
# [7]	valid_0's l2: 0.0591894
# [8]	valid_0's l2: 0.0535408
# [9]	valid_0's l2: 0.0486831
# [10]	valid_0's l2: 0.0440443
# [11]	valid_0's l2: 0.0401069
# [12]	valid_0's l2: 0.0370256
# [13]	valid_0's l2: 0.0344538
# [14]	valid_0's l2: 0.0325564
# [15]	valid_0's l2: 0.0302739
# [16]	valid_0's l2: 0.0282998
# [17]	valid_0's l2: 0.0269834
# [18]	valid_0's l2: 0.0259423
# [19]	valid_0's l2: 0.0251014
# [20]	valid_0's l2: 0.0242759
# [21]	valid_0's l2: 0.0236152
# [22]	valid_0's l2: 0.0230256
# [23]	valid_0's l2: 0.0225929
# [24]	valid_0's l2: 0.0222628
# [25]	valid_0's l2: 0.0218947
# [26]	valid_0's l2: 0.0217269
# [27]	valid_0's l2: 0.0215205
# [28]	valid_0's l2: 0.0213531
# [29]	valid_0's l2: 0.0211235
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:2068: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['MoSold', 'Neighborhood', 'YearBuilt']
#   _log_warning('categorical_feature in Dataset is overridden.\n'
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:2068: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['MoSold', 'Neighborhood', 'YearBuilt']
#   _log_warning('categorical_feature in Dataset is overridden.\n'
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [30]	valid_0's l2: 0.0209388
# [31]	valid_0's l2: 0.0208262
# [32]	valid_0's l2: 0.0207873
# [33]	valid_0's l2: 0.0207763
# [34]	valid_0's l2: 0.0207014
# [35]	valid_0's l2: 0.0207345
# [36]	valid_0's l2: 0.0207752
# [37]	valid_0's l2: 0.0208128
# [38]	valid_0's l2: 0.0207089
# [39]	valid_0's l2: 0.0206272
# [40]	valid_0's l2: 0.0206381
# [41]	valid_0's l2: 0.0206165
# [42]	valid_0's l2: 0.0205542
# [43]	valid_0's l2: 0.0205655
# [44]	valid_0's l2: 0.0206234
# [45]	valid_0's l2: 0.0206116
# [46]	valid_0's l2: 0.0206403
# [47]	valid_0's l2: 0.0205818
# [48]	valid_0's l2: 0.0205585
# [49]	valid_0's l2: 0.0206423
# [50]	valid_0's l2: 0.0206447
# [51]	valid_0's l2: 0.0207281
# [52]	valid_0's l2: 0.0206989
# Early stopping, best iteration is:
# [42]	valid_0's l2: 0.0205542
# [1]	valid_0's l2: 0.123114
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's l2: 0.103904
# [3]	valid_0's l2: 0.0885787
# [4]	valid_0's l2: 0.0752914
# [5]	valid_0's l2: 0.0646154
# [6]	valid_0's l2: 0.0563899
# [7]	valid_0's l2: 0.0494126
# [8]	valid_0's l2: 0.043499
# [9]	valid_0's l2: 0.0383911
# [10]	valid_0's l2: 0.0341169
# [11]	valid_0's l2: 0.0307774
# [12]	valid_0's l2: 0.027865
# [13]	valid_0's l2: 0.0252888
# [14]	valid_0's l2: 0.0232879
# [15]	valid_0's l2: 0.0215192
# [16]	valid_0's l2: 0.0202231
# [17]	valid_0's l2: 0.0191227
# [18]	valid_0's l2: 0.0180166
# [19]	valid_0's l2: 0.0171939
# [20]	valid_0's l2: 0.0165723
# [21]	valid_0's l2: 0.016059
# [22]	valid_0's l2: 0.0157168
# [23]	valid_0's l2: 0.0154529
# [24]	valid_0's l2: 0.0151262
# [25]	valid_0's l2: 0.0148719
# [26]	valid_0's l2: 0.0147669
# [27]	valid_0's l2: 0.0146904
# [28]	valid_0's l2: 0.0146959
# [29]	valid_0's l2: 0.0145734
# [30]	valid_0's l2: 0.0145436
# [31]	valid_0's l2: 0.0145239
# [32]	valid_0's l2: 0.014515
# [33]	valid_0's l2: 0.0145449
# [34]	valid_0's l2: 0.0145277
# [35]	valid_0's l2: 0.0146295
# [36]	valid_0's l2: 0.014647
# [37]	valid_0's l2: 0.0146385
# [38]	valid_0's l2: 0.0146878
# [39]	valid_0's l2: 0.0146677
# [40]	valid_0's l2: 0.0147229
# [41]	valid_0's l2: 0.0146954
# [42]	valid_0's l2: 0.0146482
# Early stopping, best iteration is:
# [32]	valid_0's l2: 0.014515
# [1]	valid_0's l2: 0.135873
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's l2: 0.115523
# [3]	valid_0's l2: 0.0999544
# [4]	valid_0's l2: 0.0869625
# [5]	valid_0's l2: 0.0761719
# [6]	valid_0's l2: 0.0673462
# [7]	valid_0's l2: 0.0602259
# [8]	valid_0's l2: 0.0537633
# [9]	valid_0's l2: 0.0483368
# [10]	valid_0's l2: 0.0445544
# [11]	valid_0's l2: 0.0406346
# [12]	valid_0's l2: 0.0376509
# [13]	valid_0's l2: 0.0353722
# [14]	valid_0's l2: 0.0330787
# [15]	valid_0's l2: 0.0313166
# [16]	valid_0's l2: 0.0296203
# [17]	valid_0's l2: 0.0283255
# [18]	valid_0's l2: 0.0272639
# [19]	valid_0's l2: 0.0262464
# [20]	valid_0's l2: 0.0256629
# [21]	valid_0's l2: 0.0250506
# [22]	valid_0's l2: 0.0243758
# [23]	valid_0's l2: 0.0239138
# [24]	valid_0's l2: 0.0235089
# [25]	valid_0's l2: 0.0231432
# [26]	valid_0's l2: 0.0229872
# [27]	valid_0's l2: 0.0227551
# [28]	valid_0's l2: 0.0226013
# [29]	valid_0's l2: 0.022455
# [30]	valid_0's l2: 0.0222945
# [31]	valid_0's l2: 0.0222002
# [32]	valid_0's l2: 0.0219611
# [33]	valid_0's l2: 0.0218193
# [34]	valid_0's l2: 0.0217958
# [35]	valid_0's l2: 0.021798
# [36]	valid_0's l2: 0.0217679
# [37]	valid_0's l2: 0.0216713
# [38]	valid_0's l2: 0.0216434
# [39]	valid_0's l2: 0.0215873
# [40]	valid_0's l2: 0.0215038
# [41]	valid_0's l2: 0.0214874
# [42]	valid_0's l2: 0.0214874
# [43]	valid_0's l2: 0.0214497
# [44]	valid_0's l2: 0.0213934
# [45]	valid_0's l2: 0.0213498
# [46]	valid_0's l2: 0.0212886
# [47]	valid_0's l2: 0.0213467
# [48]	valid_0's l2: 0.0214265
# [49]	valid_0's l2: 0.0214563
# [50]	valid_0's l2: 0.0214819
# [51]	valid_0's l2: 0.021377
# [52]	valid_0's l2: 0.0213058
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:2068: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['MoSold', 'Neighborhood', 'YearBuilt']
#   _log_warning('categorical_feature in Dataset is overridden.\n'
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [53]	valid_0's l2: 0.0212969
# [54]	valid_0's l2: 0.0212439
# [55]	valid_0's l2: 0.0212567
# [56]	valid_0's l2: 0.0212015
# [57]	valid_0's l2: 0.0212232
# [58]	valid_0's l2: 0.0212257
# [59]	valid_0's l2: 0.0211673
# [60]	valid_0's l2: 0.021198
# [61]	valid_0's l2: 0.0211812
# [62]	valid_0's l2: 0.021213
# [63]	valid_0's l2: 0.0211635
# [64]	valid_0's l2: 0.0211287
# [65]	valid_0's l2: 0.0211461
# [66]	valid_0's l2: 0.0211128
# [67]	valid_0's l2: 0.0210641
# [68]	valid_0's l2: 0.0210539
# [69]	valid_0's l2: 0.0210663
# [70]	valid_0's l2: 0.0210475
# [71]	valid_0's l2: 0.0210878
# [72]	valid_0's l2: 0.0211056
# [73]	valid_0's l2: 0.0210817
# [74]	valid_0's l2: 0.021141
# [75]	valid_0's l2: 0.0212118
# [76]	valid_0's l2: 0.02119
# [77]	valid_0's l2: 0.0211977
# [78]	valid_0's l2: 0.0211674
# [79]	valid_0's l2: 0.0211429
# [80]	valid_0's l2: 0.021171
# Early stopping, best iteration is:
# [70]	valid_0's l2: 0.0210475
# [1]	valid_0's l2: 0.153863
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's l2: 0.131994
# [3]	valid_0's l2: 0.114872
# [4]	valid_0's l2: 0.100392
# [5]	valid_0's l2: 0.0883452
# [6]	valid_0's l2: 0.0778995
# [7]	valid_0's l2: 0.0694623
# [8]	valid_0's l2: 0.062181
# [9]	valid_0's l2: 0.056223
# [10]	valid_0's l2: 0.0510531
# [11]	valid_0's l2: 0.0465682
# [12]	valid_0's l2: 0.0428447
# [13]	valid_0's l2: 0.0394254
# [14]	valid_0's l2: 0.0368479
# [15]	valid_0's l2: 0.0344245
# [16]	valid_0's l2: 0.0323231
# [17]	valid_0's l2: 0.0305727
# [18]	valid_0's l2: 0.0291506
# [19]	valid_0's l2: 0.0279997
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:2065: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:2068: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['MoSold', 'Neighborhood', 'YearBuilt']
#   _log_warning('categorical_feature in Dataset is overridden.\n'
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [20]	valid_0's l2: 0.0269623
# [21]	valid_0's l2: 0.0258394
# [22]	valid_0's l2: 0.0250891
# [23]	valid_0's l2: 0.0243938
# [24]	valid_0's l2: 0.0238572
# [25]	valid_0's l2: 0.0234792
# [26]	valid_0's l2: 0.0231381
# [27]	valid_0's l2: 0.0228435
# [28]	valid_0's l2: 0.0226213
# [29]	valid_0's l2: 0.0224166
# [30]	valid_0's l2: 0.0221574
# [31]	valid_0's l2: 0.0218872
# [32]	valid_0's l2: 0.0216335
# [33]	valid_0's l2: 0.0215309
# [34]	valid_0's l2: 0.0213307
# [35]	valid_0's l2: 0.0211585
# [36]	valid_0's l2: 0.0210657
# [37]	valid_0's l2: 0.0209177
# [38]	valid_0's l2: 0.0208056
# [39]	valid_0's l2: 0.0207545
# [40]	valid_0's l2: 0.0207221
# [41]	valid_0's l2: 0.0207088
# [42]	valid_0's l2: 0.0206381
# [43]	valid_0's l2: 0.0205807
# [44]	valid_0's l2: 0.0204723
# [45]	valid_0's l2: 0.0203724
# [46]	valid_0's l2: 0.0204118
# [47]	valid_0's l2: 0.0204199
# [48]	valid_0's l2: 0.0204026
# [49]	valid_0's l2: 0.0204558
# [50]	valid_0's l2: 0.0204331
# [51]	valid_0's l2: 0.0204688
# [52]	valid_0's l2: 0.0204852
# [53]	valid_0's l2: 0.0204485
# [54]	valid_0's l2: 0.0204661
# [55]	valid_0's l2: 0.0204604
# Early stopping, best iteration is:
# [45]	valid_0's l2: 0.0203724

# %%
print("rmse(cv)：avg={}".format(np.mean(rmse_list)))
print("rmse(cv)：std={}".format(np.std(rmse_list)))
print("r2(cv)：avg={}".format(np.mean(r2_list)))
print("r2(cv)：std={}".format(np.std(r2_list)))
# Out:
# rmse(cv)：avg=0.13567668393500648
# rmse(cv)：std=0.010083291018753764
# r2(cv)：avg=0.8838871212556138
# r2(cv)：std=0.01483257199404251

# %%
# submission
df_sub = df.loc[(df['train_test']==3), :].drop(columns=['train_test','Id','SalePrice'], axis=1)
print(df_sub.shape)
df_sub.head(3)
# Out:
# (1459, 39)
#    GrLivArea  TotalBsmtSF  LotArea  BsmtFinSF1  GarageArea  OverallQual  \
# 1        941          941     8604         941         564            5
# 4        907          907    16269         625         343            5
# 5       1174          864    12250         781         528            5
#
#    1stFlrSF  YearBuilt  LotFrontage  Neighborhood  ...  \
# 1       941       1978           75            12  ...
# 4       907       1978           70             5  ...
# 5      1174       1978           70             5  ...
#
#    TotalBsmtSF_BY_YearBuilt  GarageArea_BY_Neighborhood  \
# 1                       -97                         140
# 4                      -131                        -226
# 5                      -174                         -41
#
#    GarageArea_BY_OverallQual  GarageArea_BY_YearBuilt  \
# 1                        179                       51
# 4                        -41                     -169
# 5                        143                       15
#
#    1stFlrSF_BY_Neighborhood  1stFlrSF_BY_OverallQual  1stFlrSF_BY_YearBuilt  \
# 1                      -234                     -128                   -243
# 4                      -266                     -162                   -277
# 5                         0                      104                    -10
#
#    YearRemodAdd_BY_Neighborhood  YearRemodAdd_BY_OverallQual  \
# 1                             7                            4
# 4                           -21                            4
# 5                           -21                            4
#
#    YearRemodAdd_BY_YearBuilt
# 1                         -2
# 4                         -2
# 5                         -2
#
# [3 rows x 39 columns]

# %%
df_out = df.loc[(df['train_test']==3), :][['Id']]
print(df_out.shape)
df_out.head(3)
# Out:
# (1459, 1)
#      Id
# 1  1804
# 4  1879
# 5  2171

# %%
# 予測
for i in range(len(model_list)):
  ary_pred = model_list[i].predict(df_sub)
  df_out["pred_{}".format(i)] = np.exp(ary_pred)
df_out.head(3)
# Out:
#      Id         pred_0         pred_1         pred_2         pred_3  \
# 1  1804  147835.098645  144037.927359  140198.214541  142410.476388
# 4  1879  132744.425268  133231.597727  136161.414150  130074.288904
# 5  2171  155317.862615  147985.986522  157095.691178  155282.660090
#
#           pred_4
# 1  141389.092571
# 4  141068.714199
# 5  149992.825472

# %%
df_out['SalePrice'] = np.mean(df_out.iloc[:, 1:len(model_list)+1], axis=1)
df_out = df_out[['Id', 'SalePrice']]
df_out.head(3)
# Out:
#      Id      SalePrice
# 1  1804  143174.161901
# 4  1879  134656.088050
# 5  2171  153135.005175

# %%
df_out.to_csv(OUTPUT_PATH + OUTPUT_FILE, index=False)
df_out.head(3)
# Out:
#      Id      SalePrice
# 1  1804  143174.161901
# 4  1879  134656.088050
# 5  2171  153135.005175
